# %%
import tensorflow as tf
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# x and y data
x_train = [1, 2, 3]
y_train = [1, 2, 3]

# 주어진 x와 y에 대하여 W, b의 값을 정의하여야 하는데, 이를 tensorflow에서는 Varialbe이란 node로 정의할 수 있음
# 여기서 variable이란 개념은 tensorflow를 실행시키면 tensorflow가 자체적으로 변경시키는 값이다 라는 의미
# trainable이라고도 불림
# W와 b의 값을 모르니, random_normal로 설정하면서 shape을 값이 하나인 1차원 array(tensor)인 [1]로 정의
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

# our hypothesis xW+b
hypothesis = x_train * W + b

# %%
# cost/loss function
# tf.square: 제곱
# tf.reduce_mean: 평균을 구함
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# %%
# minimize cost
# tensorflow에는 위와 같은 minimize cost하는데 여러가지 방법이 있는데 그 중에 하나인 gradient descent를 사용할 것임
# gradient descent를 사용할 땐, tf.train.GradientDescentOptimizer
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# 여기까지 graph를 build 했음

# %%
# 구현한 graph를 실행하기 위해선 session을 만들어야 함
# 그리고 우리가 tf.Variable을 만들었는데, variable을 사용하기 위해서는
# 반드시, sess.run(tf.global_variables_initializer()) 을 명령해주어야 함

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# 0 1.3347182 [-0.16866374] [1.6860199]
# 20 0.45041832 [0.19313242] [1.7417772]
# 40 0.40217003 [0.26027253] [1.6727741]
# 60 0.3651947 [0.29781932] [1.5953836]
# 80 0.33167514 [0.3310842] [1.5205231]
# 100 0.3012326 [0.362546] [1.4490752]
# 120 0.27358443 [0.39250633] [1.3809752]
# 140 0.24847376 [0.42105648] [1.3160747]
# 160 0.22566791 [0.44826466] [1.2542242]
# 180 0.20495522 [0.47419414] [1.1952803]
# 200 0.18614356 [0.4989051] [1.1391065]
# 220 0.16905852 [0.52245474] [1.0855725]
# 240 0.15354161 [0.5448977] [1.0345545]
# 260 0.13944902 [0.5662857] [0.9859344]
# 280 0.12664981 [0.5866687] [0.9395991]
# 300 0.11502541 [0.6060938] [0.89544135]
# 320 0.10446792 [0.6246059] [0.853359]
# 340 0.094879426 [0.642248] [0.8132542]
# 360 0.086170994 [0.65906113] [0.77503407]
# 380 0.078261845 [0.67508405] [0.7386104]
# 400 0.07107869 [0.6903539] [0.7038984]
# 420 0.064554766 [0.7049062] [0.6708177]
# 440 0.05862968 [0.7187745] [0.6392917]
# 460 0.05324845 [0.731991] [0.60924745]
# 480 0.048361078 [0.74458647] [0.5806151]
# 500 0.04392229 [0.75658995] [0.5533283]
# 520 0.039890938 [0.76802933] [0.52732396]
# 540 0.03622961 [0.7789311] [0.5025416]
# 560 0.0329043 [0.78932047] [0.47892404]
# 580 0.029884225 [0.79922163] [0.45641643]
# 600 0.027141312 [0.80865747] [0.43496647]
# 620 0.024650177 [0.8176499] [0.41452467]
# 640 0.022387689 [0.82621974] [0.39504355]
# 660 0.02033287 [0.83438677] [0.37647796]
# 680 0.018466642 [0.84216994] [0.3587849]
# 700 0.016771698 [0.8495873] [0.34192342]
# 720 0.015232332 [0.8566561] [0.3258543]
# 740 0.013834263 [0.8633927] [0.3105404]
# 760 0.0125644915 [0.8698128] [0.29594615]
# 780 0.011411269 [0.875931] [0.28203776]
# 800 0.01036389 [0.88176185] [0.26878306]
# 820 0.009412657 [0.8873186] [0.25615126]
# 840 0.008548728 [0.8926142] [0.24411304]
# 860 0.007764093 [0.8976609] [0.23264064]
# 880 0.007051479 [0.9024705] [0.22170739]
# 900 0.0064042546 [0.9070541] [0.21128795]
# 920 0.0058164434 [0.91142225] [0.20135814]
# 940 0.005282589 [0.91558504] [0.19189505]
# 960 0.004797736 [0.91955227] [0.18287668]
# 980 0.004357367 [0.923333] [0.17428207]
# 1000 0.0039574434 [0.9269361] [0.16609149]
# 1020 0.0035942022 [0.9303699] [0.15828574]
# 1040 0.003264311 [0.9336422] [0.15084687]
# 1060 0.002964705 [0.9367608] [0.14375761]
# 1080 0.0026925895 [0.9397328] [0.13700156]
# 1100 0.0024454526 [0.94256514] [0.13056298]
# 1120 0.002221003 [0.94526434] [0.12442704]
# 1140 0.0020171509 [0.9478367] [0.11857941]
# 1160 0.0018320052 [0.9502883] [0.11300656]
# 1180 0.001663859 [0.9526245] [0.10769563]
# 1200 0.001511138 [0.954851] [0.10263433]
# 1220 0.0013724392 [0.95697284] [0.0978109]
# 1240 0.0012464724 [0.958995] [0.09321414]
# 1260 0.0011320665 [0.9609221] [0.08883336]
# 1280 0.0010281587 [0.96275854] [0.08465853]
# 1300 0.00093379593 [0.9645087] [0.08067994]
# 1320 0.00084808515 [0.9661767] [0.07688829]
# 1340 0.0007702447 [0.9677662] [0.07327483]
# 1360 0.00069955364 [0.9692811] [0.06983123]
# 1380 0.00063534343 [0.97072476] [0.06654944]
# 1400 0.000577029 [0.9721006] [0.06342188]
# 1420 0.00052406633 [0.9734118] [0.06044129]
# 1440 0.00047596838 [0.9746613] [0.05760079]
# 1460 0.0004322785 [0.97585213] [0.05489375]
# 1480 0.00039260124 [0.976987] [0.05231394]
# 1500 0.00035656904 [0.97806853] [0.04985538]
# 1520 0.0003238424 [0.9790991] [0.0475124]
# 1540 0.00029412002 [0.9800814] [0.04527953]
# 1560 0.0002671222 [0.9810176] [0.04315155]
# 1580 0.00024260541 [0.9819097] [0.04112354]
# 1600 0.00022033862 [0.9827599] [0.03919087]
# 1620 0.00020011577 [0.98357004] [0.03734903]
# 1640 0.0001817483 [0.9843423] [0.03559376]
# 1660 0.00016506568 [0.9850781] [0.03392101]
# 1680 0.00014991467 [0.98577935] [0.03232683]
# 1700 0.00013615684 [0.9864477] [0.03080759]
# 1720 0.00012365854 [0.98708457] [0.02935974]
# 1740 0.000112309215 [0.9876916] [0.02797996]
# 1760 0.00010200168 [0.98827] [0.02666501]
# 1780 9.26399e-05 [0.9888212] [0.02541188]
# 1800 8.41354e-05 [0.9893466] [0.02421765]
# 1820 7.6413846e-05 [0.98984724] [0.0230795]
# 1840 6.939893e-05 [0.99032456] [0.0219948]
# 1860 6.3030064e-05 [0.9907792] [0.02096109]
# 1880 5.7245223e-05 [0.99121255] [0.01997598]
# 1900 5.1989962e-05 [0.99162555] [0.01903716]
# 1920 4.7219237e-05 [0.9920191] [0.01814247]
# 1940 4.288446e-05 [0.99239415] [0.01728986]
# 1960 3.894793e-05 [0.99275166] [0.01647728]
# 1980 3.5373574e-05 [0.99309224] [0.01570291]
# 2000 3.2126776e-05 [0.9934169] [0.01496492]
